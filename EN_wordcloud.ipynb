# %% [markdown]
# <a href="https://colab.research.google.com/github/RoRdil31/Bigdata-Analysis/blob/main/EN_wordcloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install fonts-nanum* -qq

# %%
import matplotlib.font_manager as fm

sys_font = fm.findSystemFonts()

[f for f in sys_font if 'Nanum' in f]
# Out:
# ['/usr/share/fonts/truetype/nanum/NanumMyeongjoBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBarunpenB.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicEcoExtraBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquare_acR.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBarunGothic-YetHangul.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBarunGothicBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareL.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumMyeongjo.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicEcoBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBrush.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBarunGothicUltraLight.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquare_acL.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBarunGothicLight.ttf',
# ...

# %%
# !pip install konlpy wordcloud

# %%
with open('datafile.txt','r',encoding='utf-8') as f:
  doc_ko = f.read()
doc_ko
# Out:
# 'Bat\nBark\nBill\nBow\nBox\nBridge\nCast\nClose\nClub\nClip\nCrane\nDate\nDraw\nFace\nFile\nFly\nBat\nBark\nBill\nDraw\nFace\nFile\nFly\nBat\nBark\nBill\nCrane\nDate\nDraw\nFace\nFile\nFly\nBat\nBark\nBill\nBow\nBox\nBow\nBox\nBridge\nCast\nClose\nClub\nClip\nCrane\nDate\nDraw\nFace\nFrame\nGolf\nHinge\nHit\nHold\nIron\nJam\nKey\nLight\nLine\nMatch\nModel\nNail\nObject\nPark\nPlate\nPoint\nPresent\nPrint\nPump\nRock\nRoll\nRose\nRun\nScale\nSeal\nShot\nSink\nTear\nTie\nTrip\nWatch\nWave\nWind'

# %%
tokens_ko = doc_ko.split('\n')
tokens_ko
# Out:
# ['Bat',
#  'Bark',
#  'Bill',
#  'Bow',
#  'Box',
#  'Bridge',
#  'Cast',
#  'Close',
#  'Club',
#  'Clip',
#  'Crane',
#  'Date',
#  'Draw',
#  'Face',
#  'File',
#  'Fly',
#  'Bat',
#  'Bark',
#  'Bill',
#  'Draw',
#  'Face',
#  'File',
#  'Fly',
#  'Bat',
#  'Bark',
#  'Bill',
#  'Crane',
#  'Date',
#  'Draw',
#  'Face',
#  'File',
#  'Fly',
#  'Bat',
#  'Bark',
#  'Bill',
#  'Bow',
#  'Box',
#  'Bow',
#  'Box',
#  'Bridge',
#  'Cast',
#  'Close',
#  'Club',
#  'Clip',
#  'Crane',
#  'Date',
#  'Draw',
#  'Face',
#  'Frame',
#  'Golf',
#  'Hinge',
#  'Hit',
#  'Hold',
#  'Iron',
#  'Jam',
#  'Key',
#  'Light',
#  'Line',
#  'Match',
#  'Model',
#  'Nail',
#  'Object',
#  'Park',
#  'Plate',
#  'Point',
#  'Present',
#  'Print',
#  'Pump',
#  'Rock',
#  'Roll',
#  'Rose',
#  'Run',
#  'Scale',
#  'Seal',
#  'Shot',
#  'Sink',
#  'Tear',
#  'Tie',
#  'Trip',
#  'Watch',
#  'Wave',
#  'Wind']

# %%
from konlpy.corpus import kobill
import nltk
import matplotlib.pyplot as plt

# %%
ko = nltk.Text(tokens_ko,name='test')

plt.figure(figsize=(16,8))
ko.plot(50)
plt.show()

# %%
from wordcloud import WordCloud

data = ko.vocab().most_common(200)

path = '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf'
wc = WordCloud(font_path = path, relative_scaling=0.2,
               background_color='white').generate_from_frequencies(dict(data))

plt.figure()
plt.imshow(wc)
plt.axis('off')
plt.show()
